# %%
# importing a data analytics library

import pandas as pd

# %%
# read a csv file from the data folder

pd.read_csv("../data/audio_data_w_genres.csv")
# Out:
#            filename       tempo  beats  chroma_stft      rmse
# 0    blues.00081.au  103.359375     50     0.380260  0.248262  \
# 1    blues.00022.au   95.703125     44     0.306451  0.113475
# 2    blues.00031.au  151.999081     75     0.253487  0.151571
# 3    blues.00012.au  184.570312     91     0.269320  0.119072
# 4    blues.00056.au  161.499023     74     0.391059  0.137728
# ..              ...         ...    ...          ...       ...
# 995   rock.00017.au  123.046875     59     0.418812  0.166056
# 996   rock.00081.au  117.453835     56     0.335774  0.093676
# 997   rock.00004.au  103.359375     45     0.372834  0.208743
# 998   rock.00006.au  112.347147     45     0.344472  0.180163
# 999   rock.00066.au   75.999540     36     0.360098  0.042995
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate
# 0          2116.942959         1956.611056  4196.107960            0.127272  \
# ...

# %%
# store this csv file as a variable

audio_data = pd.read_csv("../data/audio_data_w_genres.csv")

# %%
# check the type of the variable - welcome to Data Frames
# you will cover this with Zubia next week
type(audio_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# preview the first five rows of the data frame
audio_data.head()
# Out:
#          filename       tempo  beats  chroma_stft      rmse
# 0  blues.00081.au  103.359375     50     0.380260  0.248262  \
# 1  blues.00022.au   95.703125     44     0.306451  0.113475
# 2  blues.00031.au  151.999081     75     0.253487  0.151571
# 3  blues.00012.au  184.570312     91     0.269320  0.119072
# 4  blues.00056.au  161.499023     74     0.391059  0.137728
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate
# 0        2116.942959         1956.611056  4196.107960            0.127272  \
# 1        1156.070496         1497.668176  2170.053545            0.058613
# 2        1331.073970         1973.643437  2900.174130            0.042967
# 3        1361.045467         1567.804596  2739.625101            0.069124
# 4        1811.076084         2052.332563  3927.809582            0.075480
#
#         mfcc1  ...     mfcc12     mfcc13    mfcc14    mfcc15    mfcc16
# 0  -26.929785  ...  14.336612 -13.821769  7.562789 -6.181372  0.330165  \
# ...

# %%
# preview the first ten rows of the data frame
audio_data.head(10)
# Out:
#          filename       tempo  beats  chroma_stft      rmse
# 0  blues.00081.au  103.359375     50     0.380260  0.248262  \
# 1  blues.00022.au   95.703125     44     0.306451  0.113475
# 2  blues.00031.au  151.999081     75     0.253487  0.151571
# 3  blues.00012.au  184.570312     91     0.269320  0.119072
# 4  blues.00056.au  161.499023     74     0.391059  0.137728
# 5  blues.00058.au  107.666016     51     0.356588  0.162028
# 6  blues.00066.au  161.499023     80     0.374710  0.110496
# 7  blues.00060.au  151.999081     74     0.430894  0.196222
# 8  blues.00025.au   92.285156     45     0.290948  0.089222
# 9  blues.00014.au  151.999081     70     0.329163  0.066981
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate
# 0        2116.942959         1956.611056  4196.107960            0.127272  \
# 1        1156.070496         1497.668176  2170.053545            0.058613
# 2        1331.073970         1973.643437  2900.174130            0.042967
# ...

# %%
pd.set_option('display.max_columns', None) # add this code if you want to view all the columns
audio_data.head()
# Out:
#          filename       tempo  beats  chroma_stft      rmse
# 0  blues.00081.au  103.359375     50     0.380260  0.248262  \
# 1  blues.00022.au   95.703125     44     0.306451  0.113475
# 2  blues.00031.au  151.999081     75     0.253487  0.151571
# 3  blues.00012.au  184.570312     91     0.269320  0.119072
# 4  blues.00056.au  161.499023     74     0.391059  0.137728
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate
# 0        2116.942959         1956.611056  4196.107960            0.127272  \
# 1        1156.070496         1497.668176  2170.053545            0.058613
# 2        1331.073970         1973.643437  2900.174130            0.042967
# 3        1361.045467         1567.804596  2739.625101            0.069124
# 4        1811.076084         2052.332563  3927.809582            0.075480
#
#         mfcc1       mfcc2      mfcc3      mfcc4      mfcc5      mfcc6
# 0  -26.929785  107.334008 -46.809993  40.932634 -21.463776  24.816275  \
# ...

# %%
# check the size of the file
audio_data.shape # number of rows and columns
# Out:
# (1000, 30)

# %%
# check the names of the columns
list(audio_data)
# Out:
# ['filename',
#  'tempo',
#  'beats',
#  'chroma_stft',
#  'rmse',
#  'spectral_centroid',
#  'spectral_bandwidth',
#  'rolloff',
#  'zero_crossing_rate',
#  'mfcc1',
#  'mfcc2',
#  'mfcc3',
#  'mfcc4',
#  'mfcc5',
#  'mfcc6',
#  'mfcc7',
#  'mfcc8',
#  'mfcc9',
#  'mfcc10',
#  'mfcc11',
#  'mfcc12',
#  'mfcc13',
#  'mfcc14',
#  'mfcc15',
#  'mfcc16',
#  'mfcc17',
#  'mfcc18',
#  'mfcc19',
#  'mfcc20',
#  'label']

# %%
audio_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename            1000 non-null   object
#  1   tempo               1000 non-null   float64
#  2   beats               1000 non-null   int64
#  3   chroma_stft         1000 non-null   float64
#  4   rmse                1000 non-null   float64
#  5   spectral_centroid   1000 non-null   float64
#  6   spectral_bandwidth  1000 non-null   float64
#  7   rolloff             1000 non-null   float64
#  8   zero_crossing_rate  1000 non-null   float64
#  9   mfcc1               1000 non-null   float64
#  10  mfcc2               1000 non-null   float64
#  11  mfcc3               1000 non-null   float64
#  12  mfcc4               1000 non-null   float64
#  13  mfcc5               1000 non-null   float64
#  14  mfcc6               1000 non-null   float64
# ...

# %%
# code to select a column - option 1

audio_data.filename
# Out:
# 0      blues.00081.au
# 1      blues.00022.au
# 2      blues.00031.au
# 3      blues.00012.au
# 4      blues.00056.au
#             ...
# 995     rock.00017.au
# 996     rock.00081.au
# 997     rock.00004.au
# 998     rock.00006.au
# 999     rock.00066.au
# Name: filename, Length: 1000, dtype: object

# %%
# code to select a column - option 2

audio_data["filename"]
# Out:
# 0      blues.00081.au
# 1      blues.00022.au
# 2      blues.00031.au
# 3      blues.00012.au
# 4      blues.00056.au
#             ...
# 995     rock.00017.au
# 996     rock.00081.au
# 997     rock.00004.au
# 998     rock.00006.au
# 999     rock.00066.au
# Name: filename, Length: 1000, dtype: object

# %%
# what are the different labels we have

audio_data.label.value_counts()
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: count, dtype: int64

# %%
# what is the average tempo of all the audio files
# the describe function gives summary statistics for all the numerical columns in our dataset

audio_data.describe()
# Out:
#              tempo        beats  chroma_stft         rmse  spectral_centroid
# count  1000.000000  1000.000000  1000.000000  1000.000000        1000.000000  \
# mean    119.601702    57.138000     0.378656     0.130929        2201.834226
# std      28.297367    14.225728     0.081689     0.065685         715.961347
# min      54.978391    18.000000     0.171782     0.005276         569.930721
# 25%      99.384014    47.000000     0.319641     0.086625        1627.793931
# 50%     117.453835    56.000000     0.383075     0.122448        2209.468780
# 75%     135.999178    65.250000     0.435974     0.175793        2691.969702
# max     234.907670   117.000000     0.663573     0.398012        4434.439444
#
#        spectral_bandwidth      rolloff  zero_crossing_rate        mfcc1
# count         1000.000000  1000.000000         1000.000000  1000.000000  \
# mean          2242.559613  4571.702159            0.103637  -144.479173
# ...

# %%
# average for just the tempo
print("The average tempo is:", round(audio_data.tempo.mean(), 2))
# Out:
# The average tempo is: 119.6

# %%
# average tempo of hiphop
# subset the audio data

audio_data[audio_data.label == "hiphop"]
# Out:
#             filename       tempo  beats  chroma_stft      rmse
# 400  hiphop.00034.au  198.768029     97     0.469924  0.227912  \
# 401  hiphop.00005.au   71.777344     34     0.490495  0.261760
# 402  hiphop.00010.au   95.703125     47     0.427337  0.171693
# 403  hiphop.00020.au  117.453835     55     0.490141  0.175981
# 404  hiphop.00080.au   95.703125     47     0.403660  0.141419
# ..               ...         ...    ...          ...       ...
# 495  hiphop.00063.au   92.285156     45     0.445494  0.186188
# 496  hiphop.00044.au  117.453835     56     0.355542  0.038050
# 497  hiphop.00038.au  184.570312     84     0.398418  0.269266
# 498  hiphop.00070.au   95.703125     47     0.431061  0.278913
# 499  hiphop.00025.au  107.666016     50     0.507344  0.251695
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate
# 400        3191.044516         2735.904596  6353.994912            0.169166  \
# ...

# %%
hiphop_data = audio_data[audio_data.label == "hiphop"]

# %%
hiphop_data.shape
# Out:
# (100, 30)

# %%
hiphop_data.describe()
# Out:
#             tempo       beats  chroma_stft        rmse  spectral_centroid
# count  100.000000  100.000000   100.000000  100.000000         100.000000  \
# mean   113.976295   55.010000     0.454280    0.178280        2524.614443
# std     28.968860   14.195955     0.047112    0.059925         479.309061
# min     71.777344   34.000000     0.340055    0.038050        1469.356540
# 25%     95.703125   47.000000     0.424731    0.129165        2243.702794
# 50%    103.359375   49.000000     0.452271    0.181643        2500.875497
# 75%    117.453835   58.000000     0.482857    0.227973        2783.352967
# max    198.768029   97.000000     0.583689    0.300471        3770.091835
#
#        spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1
# count          100.000000   100.000000          100.000000  100.000000  \
# mean          2513.524297  5333.917032            0.108005 -103.074057
# std            347.182310  1004.898067            0.032030   48.468382
# ...

# %%
# average for just the tempo
print("The average tempo for hiphop is:", round(hiphop_data.tempo.mean(), 2))
# Out:
# The average tempo for hiphop is: 113.98

# %%
# save this file as a .csv file in our local data folder
hiphop_data.to_csv("../data/hiphop.csv")

# %%
# code to drop a column

audio_data.drop(["filename"], axis=1)
# Out:
#           tempo  beats  chroma_stft      rmse  spectral_centroid
# 0    103.359375     50     0.380260  0.248262        2116.942959  \
# 1     95.703125     44     0.306451  0.113475        1156.070496
# 2    151.999081     75     0.253487  0.151571        1331.073970
# 3    184.570312     91     0.269320  0.119072        1361.045467
# 4    161.499023     74     0.391059  0.137728        1811.076084
# ..          ...    ...          ...       ...                ...
# 995  123.046875     59     0.418812  0.166056        2312.030070
# 996  117.453835     56     0.335774  0.093676        2553.856706
# 997  103.359375     45     0.372834  0.208743        1345.850763
# 998  112.347147     45     0.344472  0.180163        1675.475369
# 999   75.999540     36     0.360098  0.042995        2209.357588
#
#      spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1
# 0           1956.611056  4196.107960            0.127272  -26.929785  \
# ...

# %%
# code to drop column and store as a separate data frame variable
# audio data one does not have the column label anymore

audio_data_1 = audio_data.drop(["filename"], axis=1)
audio_data_1.head()
# Out:
#         tempo  beats  chroma_stft      rmse  spectral_centroid
# 0  103.359375     50     0.380260  0.248262        2116.942959  \
# 1   95.703125     44     0.306451  0.113475        1156.070496
# 2  151.999081     75     0.253487  0.151571        1331.073970
# 3  184.570312     91     0.269320  0.119072        1361.045467
# 4  161.499023     74     0.391059  0.137728        1811.076084
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1
# 0         1956.611056  4196.107960            0.127272  -26.929785  \
# 1         1497.668176  2170.053545            0.058613 -233.860772
# 2         1973.643437  2900.174130            0.042967 -221.802549
# 3         1567.804596  2739.625101            0.069124 -207.208080
# 4         2052.332563  3927.809582            0.075480 -145.434568
#
#         mfcc2      mfcc3      mfcc4      mfcc5      mfcc6      mfcc7
# 0  107.334008 -46.809993  40.932634 -21.463776  24.816275 -18.945571  \
# ...

# %%
audio_data.head()
# Out:
#          filename       tempo  beats  chroma_stft      rmse
# 0  blues.00081.au  103.359375     50     0.380260  0.248262  \
# 1  blues.00022.au   95.703125     44     0.306451  0.113475
# 2  blues.00031.au  151.999081     75     0.253487  0.151571
# 3  blues.00012.au  184.570312     91     0.269320  0.119072
# 4  blues.00056.au  161.499023     74     0.391059  0.137728
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate
# 0        2116.942959         1956.611056  4196.107960            0.127272  \
# 1        1156.070496         1497.668176  2170.053545            0.058613
# 2        1331.073970         1973.643437  2900.174130            0.042967
# 3        1361.045467         1567.804596  2739.625101            0.069124
# 4        1811.076084         2052.332563  3927.809582            0.075480
#
#         mfcc1       mfcc2      mfcc3      mfcc4      mfcc5      mfcc6
# 0  -26.929785  107.334008 -46.809993  40.932634 -21.463776  24.816275  \
# ...

# %%
# code to drop column and overwrite this change to the audio_data data frame 

audio_data.drop(["filename"], axis=1, inplace=True)
audio_data.head()
# Out:
#         tempo  beats  chroma_stft      rmse  spectral_centroid
# 0  103.359375     50     0.380260  0.248262        2116.942959  \
# 1   95.703125     44     0.306451  0.113475        1156.070496
# 2  151.999081     75     0.253487  0.151571        1331.073970
# 3  184.570312     91     0.269320  0.119072        1361.045467
# 4  161.499023     74     0.391059  0.137728        1811.076084
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1
# 0         1956.611056  4196.107960            0.127272  -26.929785  \
# 1         1497.668176  2170.053545            0.058613 -233.860772
# 2         1973.643437  2900.174130            0.042967 -221.802549
# 3         1567.804596  2739.625101            0.069124 -207.208080
# 4         2052.332563  3927.809582            0.075480 -145.434568
#
#         mfcc2      mfcc3      mfcc4      mfcc5      mfcc6      mfcc7
# 0  107.334008 -46.809993  40.932634 -21.463776  24.816275 -18.945571  \
# ...
