# %%
import pandas as pd

# %%
# code to load a dataset with pandas

audio_data = pd.read_csv("audio_data_w_genres.csv")
audio_data
# Out:
#            filename       tempo  beats  chroma_stft      rmse  \
# 0    blues.00081.au  103.359375     50     0.380260  0.248262
# 1    blues.00022.au   95.703125     44     0.306451  0.113475
# 2    blues.00031.au  151.999081     75     0.253487  0.151571
# 3    blues.00012.au  184.570312     91     0.269320  0.119072
# 4    blues.00056.au  161.499023     74     0.391059  0.137728
# ..              ...         ...    ...          ...       ...
# 995   rock.00017.au  123.046875     59     0.418812  0.166056
# 996   rock.00081.au  117.453835     56     0.335774  0.093676
# 997   rock.00004.au  103.359375     45     0.372834  0.208743
# 998   rock.00006.au  112.347147     45     0.344472  0.180163
# 999   rock.00066.au   75.999540     36     0.360098  0.042995
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0          2116.942959         1956.611056  4196.107960            0.127272
# ...

# %%
# check the type of the variable auto data

type(audio_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# preview the first ten rows

audio_data.head(n=10)
# Out:
#          filename       tempo  beats  chroma_stft      rmse  \
# 0  blues.00081.au  103.359375     50     0.380260  0.248262
# 1  blues.00022.au   95.703125     44     0.306451  0.113475
# 2  blues.00031.au  151.999081     75     0.253487  0.151571
# 3  blues.00012.au  184.570312     91     0.269320  0.119072
# 4  blues.00056.au  161.499023     74     0.391059  0.137728
# 5  blues.00058.au  107.666016     51     0.356588  0.162028
# 6  blues.00066.au  161.499023     80     0.374710  0.110496
# 7  blues.00060.au  151.999081     74     0.430894  0.196222
# 8  blues.00025.au   92.285156     45     0.290948  0.089222
# 9  blues.00014.au  151.999081     70     0.329163  0.066981
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0        2116.942959         1956.611056  4196.107960            0.127272
# 1        1156.070496         1497.668176  2170.053545            0.058613
# 2        1331.073970         1973.643437  2900.174130            0.042967
# ...

# %%
# check the shape

audio_data.shape
# Out:
# (1000, 30)

# %%
# check the names of the columns

list(audio_data)
# Out:
# ['filename',
#  'tempo',
#  'beats',
#  'chroma_stft',
#  'rmse',
#  'spectral_centroid',
#  'spectral_bandwidth',
#  'rolloff',
#  'zero_crossing_rate',
#  'mfcc1',
#  'mfcc2',
#  'mfcc3',
#  'mfcc4',
#  'mfcc5',
#  'mfcc6',
#  'mfcc7',
#  'mfcc8',
#  'mfcc9',
#  'mfcc10',
#  'mfcc11',
#  'mfcc12',
#  'mfcc13',
#  'mfcc14',
#  'mfcc15',
#  'mfcc16',
#  'mfcc17',
#  'mfcc18',
#  'mfcc19',
#  'mfcc20',
#  'label']

# %%
# index by row, return 1st row

audio_data.loc[0]
# Out:
# filename              blues.00081.au
# tempo                     103.359375
# beats                             50
# chroma_stft                  0.38026
# rmse                        0.248262
# spectral_centroid        2116.942959
# spectral_bandwidth       1956.611056
# rolloff                   4196.10796
# zero_crossing_rate          0.127272
# mfcc1                     -26.929785
# mfcc2                     107.334008
# mfcc3                     -46.809993
# mfcc4                      40.932634
# mfcc5                     -21.463776
# mfcc6                      24.816275
# mfcc7                     -18.945571
# mfcc8                      15.253459
# mfcc9                     -15.050104
# mfcc10                     12.262823
# mfcc11                     -15.23405
# mfcc12                     14.336612
# mfcc13                    -13.821769
# mfcc14                      7.562789
# mfcc15                     -6.181372
# mfcc16                      0.330165
# ...

# %%
# index by row, return 1 and 2 row

audio_data.loc[0:1]
# Out:
#          filename       tempo  beats  chroma_stft      rmse  \
# 0  blues.00081.au  103.359375     50     0.380260  0.248262
# 1  blues.00022.au   95.703125     44     0.306451  0.113475
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0        2116.942959         1956.611056  4196.107960            0.127272
# 1        1156.070496         1497.668176  2170.053545            0.058613
#
#         mfcc1  ...     mfcc12     mfcc13    mfcc14    mfcc15    mfcc16  \
# 0  -26.929785  ...  14.336612 -13.821769  7.562789 -6.181372  0.330165
# 1 -233.860772  ...  -2.250578   3.959198  5.322555  0.812028 -1.107202
#
#      mfcc17    mfcc18    mfcc19    mfcc20  label
# 0 -6.829571  0.965922 -7.570825  2.918987  blues
# 1 -4.556555 -2.436490  3.316913 -0.608485  blues
#
# [2 rows x 30 columns]

# %%
# select a column
# option 1

audio_data["tempo"]
# Out:
# 0      103.359375
# 1       95.703125
# 2      151.999081
# 3      184.570312
# 4      161.499023
#           ...
# 995    123.046875
# 996    117.453835
# 997    103.359375
# 998    112.347147
# 999     75.999540
# Name: tempo, Length: 1000, dtype: float64

# %%
# option 2

audio_data.tempo
# Out:
# 0      103.359375
# 1       95.703125
# 2      151.999081
# 3      184.570312
# 4      161.499023
#           ...
# 995    123.046875
# 996    117.453835
# 997    103.359375
# 998    112.347147
# 999     75.999540
# Name: tempo, Length: 1000, dtype: float64

# %%
# drop a column

audio_data.drop(["beats", "tempo"], axis = 1, inplace = True)

# %%
# check the names of the columns

list(audio_data)
# Out:
# ['filename',
#  'chroma_stft',
#  'rmse',
#  'spectral_centroid',
#  'spectral_bandwidth',
#  'rolloff',
#  'zero_crossing_rate',
#  'mfcc1',
#  'mfcc2',
#  'mfcc3',
#  'mfcc4',
#  'mfcc5',
#  'mfcc6',
#  'mfcc7',
#  'mfcc8',
#  'mfcc9',
#  'mfcc10',
#  'mfcc11',
#  'mfcc12',
#  'mfcc13',
#  'mfcc14',
#  'mfcc15',
#  'mfcc16',
#  'mfcc17',
#  'mfcc18',
#  'mfcc19',
#  'mfcc20',
#  'label']

# %%
# code to save the file to a .csv file

audio_data.to_csv('audio_data_cleaned.csv')

# %%
# optional - look at correlations between the variables

audio_data.corr()
# Out:
#                     chroma_stft      rmse  spectral_centroid  \
# chroma_stft            1.000000  0.499577           0.615524
# rmse                   0.499577  1.000000           0.509984
# spectral_centroid      0.615524  0.509984           1.000000
# spectral_bandwidth     0.517482  0.529768           0.904438
# rolloff                0.597910  0.537718           0.979633
# zero_crossing_rate     0.554735  0.332119           0.874755
# mfcc1                  0.659294  0.807260           0.720831
# mfcc2                 -0.598495 -0.483765          -0.940171
# mfcc3                 -0.054431  0.139339           0.187999
# mfcc4                  0.264226  0.008695          -0.136839
# mfcc5                 -0.010116  0.108700           0.069032
# mfcc6                  0.416953  0.125782           0.017572
# mfcc7                  0.067536  0.167592           0.215744
# mfcc8                  0.509829  0.179000           0.134347
# ...

# %%
# optional - subset a dataframe by file name

audio_data[audio_data.filename == 'blues.00081.au']
# Out:
#          filename  chroma_stft      rmse  spectral_centroid  \
# 0  blues.00081.au      0.38026  0.248262        2116.942959
#
#    spectral_bandwidth     rolloff  zero_crossing_rate      mfcc1       mfcc2  \
# 0         1956.611056  4196.10796            0.127272 -26.929785  107.334008
#
#        mfcc3  ...     mfcc12     mfcc13    mfcc14    mfcc15    mfcc16  \
# 0 -46.809993  ...  14.336612 -13.821769  7.562789 -6.181372  0.330165
#
#      mfcc17    mfcc18    mfcc19    mfcc20  label
# 0 -6.829571  0.965922 -7.570825  2.918987  blues
#
# [1 rows x 28 columns]

# %%
# optional - loop through a data frame
# thankfully we have lots of libraries that we dont need to do that

for index, row in audio_data.iterrows():
      print(row["filename"])
# Out:
# blues.00081.au
# blues.00022.au
# blues.00031.au
# blues.00012.au
# blues.00056.au
# blues.00058.au
# blues.00066.au
# blues.00060.au
# blues.00025.au
# blues.00014.au
# blues.00093.au
# blues.00097.au
# blues.00040.au
# blues.00096.au
# blues.00095.au
# blues.00068.au
# blues.00071.au
# blues.00080.au
# blues.00094.au
# blues.00029.au
# blues.00067.au
# blues.00033.au
# blues.00001.au
# blues.00098.au
# blues.00087.au
# blues.00083.au
# blues.00055.au
# blues.00077.au
# blues.00076.au
# blues.00049.au
# blues.00011.au
# blues.00048.au
# blues.00053.au
# blues.00064.au
# blues.00051.au
# blues.00013.au
# blues.00045.au
# blues.00075.au
# blues.00082.au
# blues.00091.au
# blues.00035.au
# blues.00057.au
# blues.00016.au
# blues.00037.au
# blues.00050.au
# blues.00046.au
# blues.00002.au
# blues.00038.au
# blues.00006.au
# blues.00003.au
# blues.00043.au
# blues.00092.au
# blues.00034.au
# blues.00005.au
# blues.00069.au
# blues.00023.au
# blues.00086.au
# blues.00008.au
# ...
