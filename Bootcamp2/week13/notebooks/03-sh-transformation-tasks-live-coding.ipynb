# %%
import pandas as pd

# %%
# this code gives you the file path of your notebooks

import os

os.getcwd()
# Out:
# '/Users/shaq/Documents/waia-academy/Bootcamp2/week13/notebooks'

# %%
users_data = pd.read_pickle("../data/users_data_final.pkl")

# %%
users_data.head()
# Out:
#                                 user_id  number_transactions
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0  \
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
# 2  573de577-49ef-42b9-83da-d3cfb817b5c1                  2.0
# 3  d6b66b9d-7c8f-4257-a682-e136f640b7e3                  NaN
# 4  fade0b20-7594-4d9a-84cd-c02f79b1b526                  1.0
#
#    total_amount_usd  age           job  marital  education  default  housing
# 0            2143.0   58    management  married   tertiary    False     True  \
# 1               NaN   44    technician   single  secondary    False     True
# 2               2.0   33  entrepreneur  married  secondary    False     True
# 3               NaN   47   blue-collar  married       None    False     True
# 4               1.0   33          None   single       None    False    False
#
#     loan contact  duration  campaign  pdays  previous poutcome  term_deposit
# ...

# %%
type(users_data)
# Out:
# pandas.core.frame.DataFrame

# %%
users_data.shape
# Out:
# (45209, 19)

# %%
users_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45209 entries, 0 to 45215
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45209 non-null  object
#  1   number_transactions  35210 non-null  float64
#  2   total_amount_usd     35210 non-null  float64
#  3   age                  45209 non-null  int64
#  4   job                  44921 non-null  object
#  5   marital              45209 non-null  object
#  6   education            43352 non-null  object
#  7   default              45209 non-null  bool
#  8   housing              45209 non-null  bool
#  9   loan                 45209 non-null  bool
#  10  contact              32191 non-null  object
#  11  duration             45209 non-null  int64
#  12  campaign             45209 non-null  int64
#  13  pdays                45209 non-null  int64
#  14  previous             45209 non-null  int64
# ...

# %%
# code to subset data frame with data type object

users_data.select_dtypes(['object'])
# Out:
#                                     user_id           job   marital
# 0      9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6    management   married  \
# 1      bb92765a-08de-4963-b432-496524b39157    technician    single
# 2      573de577-49ef-42b9-83da-d3cfb817b5c1  entrepreneur   married
# 3      d6b66b9d-7c8f-4257-a682-e136f640b7e3   blue-collar   married
# 4      fade0b20-7594-4d9a-84cd-c02f79b1b526          None    single
# ...                                     ...           ...       ...
# 45211  a218c1d6-880a-4431-a314-a1bd3dc36b21    technician   married
# 45212  6a6bf402-9416-4e71-97c6-727e8298a3a5       retired  divorced
# 45213  be32ba96-b178-4b54-b32a-f75b714793df       retired   married
# 45214  44623a48-4e9b-48fd-b155-a17d1c06a754   blue-collar   married
# 45215  5905741c-3f30-416f-8ee5-71abad035de6  entrepreneur   married
#
#        education    contact poutcome   device
# 0       tertiary       None     None   mobile
# 1      secondary       None     None  desktop
# ...

# %%
# code to identify variables with data type object

list(users_data.select_dtypes(['object']).columns)
# Out:
# ['user_id', 'job', 'marital', 'education', 'contact', 'poutcome', 'device']

# %%
# count the number of elements in the list

len(list(users_data.select_dtypes(['object']).columns))
# Out:
# 7

# %%
print("# of variables with data type object:",
      len(users_data.select_dtypes(['object']).columns))
# Out:
# # of variables with data type object: 7

# %%
print(f"Number of variables with data type object is {len(list(users_data.select_dtypes(['object']).columns))}")
# Out:
# Number of variables with data type object is 7

# %%
# code to subset data frame with numerical data types (int, float, bool)

users_data.select_dtypes(['int64', 'float64', 'bool'])
# Out:
#        number_transactions  total_amount_usd  age  default  housing   loan
# 0                      3.0            2143.0   58    False     True  False  \
# 1                      NaN               NaN   44    False     True  False
# 2                      2.0               2.0   33    False     True   True
# 3                      NaN               NaN   47    False     True  False
# 4                      1.0               1.0   33    False    False  False
# ...                    ...               ...  ...      ...      ...    ...
# 45211                  2.0             825.0   51    False    False  False
# 45212                  4.0            1729.0   71    False    False  False
# 45213                  2.0            5715.0   72    False    False  False
# 45214                  NaN               NaN   57    False    False  False
# 45215                  3.0            2971.0   37    False    False  False
#
#        duration  campaign  pdays  previous  term_deposit
# ...

# %%
numerical_cols = list(users_data.select_dtypes(['int64', 'float64', 'bool']).columns)
numerical_cols
# Out:
# ['number_transactions',
#  'total_amount_usd',
#  'age',
#  'default',
#  'housing',
#  'loan',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'term_deposit']

# %%
print("# of variables with numerical data types :", len(numerical_cols))
# Out:
# # of variables with numerical data types : 11

# %%
users_data.number_transactions

# histograms
# box plots
# describe
# fill na with a numerical value
# Out:
# 0        3.0
# 1        NaN
# 2        2.0
# 3        NaN
# 4        1.0
#         ...
# 45211    2.0
# 45212    4.0
# 45213    2.0
# 45214    NaN
# 45215    3.0
# Name: number_transactions, Length: 45209, dtype: float64

# %%
users_data.number_transactions.describe()
# Out:
# count    35210.000000
# mean         3.977052
# std          3.814329
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         20.000000
# Name: number_transactions, dtype: float64

# %%
users_data.device.value_counts(dropna = False).plot(kind = 'bar');

# %% [markdown]
# ### Identifying duplicated Data

# %%
# option 1 
# we have no duplicated rows of data
users_data.duplicated().sum()
# Out:
# 0

# %%
# option 2
# we have no duplicated rows of data

users_data[users_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, number_transactions, total_amount_usd, age, job, marital, education, default, housing, loan, contact, duration, campaign, pdays, previous, poutcome, term_deposit, date_joined, device]
# Index: []

# %% [markdown]
# ### Identifying missing values

# %%
users_data.isna().mean()
# Out:
# user_id                0.000000
# number_transactions    0.221173
# total_amount_usd       0.221173
# age                    0.000000
# job                    0.006370
# marital                0.000000
# education              0.041076
# default                0.000000
# housing                0.000000
# loan                   0.000000
# contact                0.287952
# duration               0.000000
# campaign               0.000000
# pdays                  0.000000
# previous               0.000000
# poutcome               0.817470
# term_deposit           0.000000
# date_joined            0.000664
# device                 0.002079
# dtype: float64

# %% [markdown]
# - How many variables contain missing data?
# - How many numerical variables contain missing data?
# - How many non numerical variables contain missing values?
# - How many variables contain more than 70% missing data?

# %%
users_data[users_data.poutcome.isnull()]
# Out:
#                                     user_id  number_transactions
# 0      9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0  \
# 1      bb92765a-08de-4963-b432-496524b39157                  NaN
# 2      573de577-49ef-42b9-83da-d3cfb817b5c1                  2.0
# 3      d6b66b9d-7c8f-4257-a682-e136f640b7e3                  NaN
# 4      fade0b20-7594-4d9a-84cd-c02f79b1b526                  1.0
# ...                                     ...                  ...
# 45208  240bce69-b3eb-49c6-9a61-f0684b919d7a                  2.0
# 45210  6ace2eec-d1a9-4ea6-810d-4acb56fd00ab                  3.0
# 45211  a218c1d6-880a-4431-a314-a1bd3dc36b21                  2.0
# 45212  6a6bf402-9416-4e71-97c6-727e8298a3a5                  4.0
# 45214  44623a48-4e9b-48fd-b155-a17d1c06a754                  NaN
#
#        total_amount_usd  age           job   marital  education  default
# 0                2143.0   58    management   married   tertiary    False  \
# ...

# %%
# this drops the poutcome variable

users_data_cleaned = users_data.drop(["poutcome"], axis = 1)
users_data_cleaned.head()
# Out:
#                                 user_id  number_transactions
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0  \
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
# 2  573de577-49ef-42b9-83da-d3cfb817b5c1                  2.0
# 3  d6b66b9d-7c8f-4257-a682-e136f640b7e3                  NaN
# 4  fade0b20-7594-4d9a-84cd-c02f79b1b526                  1.0
#
#    total_amount_usd  age           job  marital  education  default  housing
# 0            2143.0   58    management  married   tertiary    False     True  \
# 1               NaN   44    technician   single  secondary    False     True
# 2               2.0   33  entrepreneur  married  secondary    False     True
# 3               NaN   47   blue-collar  married       None    False     True
# 4               1.0   33          None   single       None    False    False
#
#     loan contact  duration  campaign  pdays  previous  term_deposit
# ...

# %%
print("Shape of data before cleaning", users_data.shape)
print("Shape of data after cleaning", users_data_cleaned.shape)
# Out:
# Shape of data before cleaning (45209, 19)
# Shape of data after cleaning (45209, 18)

# %%
list(users_data_cleaned)
# Out:
# ['user_id',
#  'number_transactions',
#  'total_amount_usd',
#  'age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'term_deposit',
#  'date_joined',
#  'device']

# %%
def identify_missing_data(df):
    """
    This function is used to identify missing data
    
    @param df pandas DataFrame
    
    @return a DataFrame with the percentage of missing data for every feature and the data types
    """
    
    percent_missing = df.isnull().mean()
    
    missing_value_df = pd.DataFrame(percent_missing).reset_index() # convert to DataFrame
    missing_value_df = missing_value_df.rename(columns = {"index" : "variable_name",
                                                                0 : "percent_missing"}) # rename columns

    missing_value_df = missing_value_df.sort_values(by = ['percent_missing'], ascending = False) # sort the values
    
    data_types_df = pd.DataFrame(df.dtypes).reset_index().rename(columns = {"index" : "variable_name",
                                                                0 : "data_type"}) # rename columns
    
    missing_value_df = missing_value_df.merge(data_types_df, on = "variable_name") # join the dataframe with datatype
    
    missing_value_df.percent_missing = round(missing_value_df.percent_missing*100, 2) # format the percent_missing
    
    return missing_value_df[missing_value_df.percent_missing > 0]

# %%
missing_df = identify_missing_data(users_data)
missing_df
# Out:
#          variable_name  percent_missing       data_type
# 0             poutcome            81.75          object
# 1              contact            28.80          object
# 2     total_amount_usd            22.12         float64
# 3  number_transactions            22.12         float64
# 4            education             4.11          object
# 5                  job             0.64          object
# 6               device             0.21          object
# 7          date_joined             0.07  datetime64[ns]

# %%
print("Number of variables with missing data:", missing_df.shape[0])
# Out:
# Number of variables with missing data: 7

# %%
type(missing_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# identifying variables that have more than 70% missing data

threshold = 70

cols_to_drop = list(missing_df[missing_df.percent_missing > threshold].variable_name)
print(f"variables with more than {threshold} missing data {cols_to_drop}")

print(f"# of variables with missing data more than {threshold}: {len(cols_to_drop)}")
# Out:
# variables with more than 70 missing data ['poutcome']
# # of variables with missing data more than 70: 1

# %%
# code that identifies all variables with 70% missing data

threshold = 70

cols_to_drop = list(missing_df[missing_df.percent_missing > threshold].variable_name)
cols_to_drop
# Out:
# ['poutcome']

# %%
# drops all variables that have more than 70% missing data

users_data_cleaned = users_data.drop(cols_to_drop, axis = 1)
users_data_cleaned.head()
# Out:
#                                 user_id  number_transactions
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0  \
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
# 2  573de577-49ef-42b9-83da-d3cfb817b5c1                  2.0
# 3  d6b66b9d-7c8f-4257-a682-e136f640b7e3                  NaN
# 4  fade0b20-7594-4d9a-84cd-c02f79b1b526                  1.0
#
#    total_amount_usd  age           job  marital  education  default  housing
# 0            2143.0   58    management  married   tertiary    False     True  \
# 1               NaN   44    technician   single  secondary    False     True
# 2               2.0   33  entrepreneur  married  secondary    False     True
# 3               NaN   47   blue-collar  married       None    False     True
# 4               1.0   33          None   single       None    False    False
#
#     loan contact  duration  campaign  pdays  previous  term_deposit
# ...

# %%
print("Shape of data before cleaning", users_data.shape)
print("Shape of data after cleaning", users_data_cleaned.shape)
# Out:
# Shape of data before cleaning (45209, 19)
# Shape of data after cleaning (45209, 18)

# %%
# we did not complete this but you can pick this up if you want to...

missing_df = identify_missing_data(users_data_cleaned)
missing_df
# Out:
#          variable_name  percent_missing       data_type
# 0              contact            28.80          object
# 1     total_amount_usd            22.12         float64
# 2  number_transactions            22.12         float64
# 3            education             4.11          object
# 4                  job             0.64          object
# 5               device             0.21          object
# 6          date_joined             0.07  datetime64[ns]

# %%
# identify variables that have data type object

object_cols = list(missing_df[missing_df.data_type == 'object'].variable_name)
object_cols
# Out:
# ['contact', 'education', 'job', 'device']

# %%
print(f"# of variables with data type object: {len(object_cols)}")
# Out:
# # of variables with data type object: 4

# %%
users_data_cleaned.device.value_counts(dropna = False)
# Out:
# device
# mobile     27504
# desktop    12112
# tablet      5499
# None          94
# Name: count, dtype: int64

# %%
users_data_cleaned.device.fillna("No device", inplace = True)

# %%
users_data_cleaned.device.value_counts(dropna = False)
# Out:
# device
# mobile       27504
# desktop      12112
# tablet        5499
# No device       94
# Name: count, dtype: int64

# %% [markdown]
# ### Load this data frame to our local data folder

# %%
# store as pickle file

users_data_cleaned.to_pickle("../data/users_data_transformed.pkl")

# %%
# check everything worked on

check = pd.read_pickle("../data/users_data_transformed.pkl")
check.shape
# Out:
# (45209, 18)

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45209 entries, 0 to 45215
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45209 non-null  object
#  1   number_transactions  35210 non-null  float64
#  2   total_amount_usd     35210 non-null  float64
#  3   age                  45209 non-null  int64
#  4   job                  44921 non-null  object
#  5   marital              45209 non-null  object
#  6   education            43352 non-null  object
#  7   default              45209 non-null  bool
#  8   housing              45209 non-null  bool
#  9   loan                 45209 non-null  bool
#  10  contact              32191 non-null  object
#  11  duration             45209 non-null  int64
#  12  campaign             45209 non-null  int64
#  13  pdays                45209 non-null  int64
#  14  previous             45209 non-null  int64
# ...

# %%
# store as a csv file

users_data_cleaned.to_csv("../data/users_data_transformed.csv", index = False)

# %%
check = pd.read_csv("../data/users_data_transformed.csv")
check.shape
# Out:
# (45209, 18)

# %%
# the csv file loses the data type for date time

check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45209 entries, 0 to 45208
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45209 non-null  object
#  1   number_transactions  35210 non-null  float64
#  2   total_amount_usd     35210 non-null  float64
#  3   age                  45209 non-null  int64
#  4   job                  44921 non-null  object
#  5   marital              45209 non-null  object
#  6   education            43352 non-null  object
#  7   default              45209 non-null  bool
#  8   housing              45209 non-null  bool
#  9   loan                 45209 non-null  bool
#  10  contact              32191 non-null  object
#  11  duration             45209 non-null  int64
#  12  campaign             45209 non-null  int64
#  13  pdays                45209 non-null  int64
#  14  previous             45209 non-null  int64
# ...
